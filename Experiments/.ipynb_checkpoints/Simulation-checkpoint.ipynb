# %%
import os
os.chdir("..")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from utils.Thesis_models import *
from utils import Thesis_viz_new as viz
from utils import synthetic_data_generation_ALL as sda

# %% [markdown]
# ## Parameters

# %%
effective_groups = list(range(3,9))
visible_groups = list(range(10,260,20))
number_of_contineous_features = 1

random_effects_distribution = 'normal'; re_intercept = (0,5) ; re_slope = (0,5)
# random_effects_distribution = 'linspace'; re_intercept = (-10,10) ; re_slope = (-10,10)

# error_type = 'on_group' ; re_error = (0,3)
error_type = 'on_target' ; re_error = (0,3)

shuffle_groups = False

# %%
results_gV = pd.DataFrame([])
itr = -1
target_y = []
modes = ['intercept', 'slope', 'both']

for mode in modes:
    
    for e in effective_groups:

        for v in visible_groups:

            seeds = [100]

            for s in seeds:

                itr = itr + 1
                print("\n",itr,mode,e,v)

                df,_ = sda.create_data(
                    n = 1000,
                    n_effective_groups = e,
                    n_visible_groups = v,
                    n_contineous_features = number_of_contineous_features,
                    mode = mode,
                    fixed_slope=(0, 1),
                    fixed_intercept=0,
                    fixed_error=(0, 1),
                    random_effects_distribution=random_effects_distribution,
                    re_intercept=re_intercept,
                    re_slope=re_slope,
                    error_type=error_type,
                    re_error=re_error,
                    random_seed=s,
                    shuffle_groups=shuffle_groups,
                    show_random_effects=False,
                )
                
                target_y.append(list(df.y))

                mse_Linear_Exclude_Group, time_Linear_Exclude_Group,_,_ = Linear_Exclude_Group(df)
                mse_Linear_Include_Group, time_Linear_Include_Group,_,_ = Linear_Include_Group(df, to_drop='gE')
                mse_linearohe, time_linearohe,_,_ = LinearOHE(df, to_drop='gE')
                mse_lmmnn, time_lmmnn,_,_ = LMMNN(df, to_drop='gE')
                mse_merf, time_merf,_,_ = MERForest(df, to_drop='gE', threshold=0.1)
                mse_armed, time_armed,_,_ = ARMED(df, to_drop='gE')

                results_gV.at[itr, 'mode'] = mode
                results_gV.at[itr, 'seed'] = s
                results_gV.at[itr, 'gE'] = e
                results_gV.at[itr, 'gV'] = v

                results_gV.at[itr, 'mse_Linear_Exclude_Group'] = mse_Linear_Exclude_Group
                results_gV.at[itr, 'time_Linear_Exclude_Group'] = time_Linear_Exclude_Group
                results_gV.at[itr, 'mse_Linear_Include_Group'] = mse_Linear_Include_Group
                results_gV.at[itr, 'time_Linear_Include_Group'] = time_Linear_Include_Group
                results_gV.at[itr, 'mse_linearohe'] = mse_linearohe
                results_gV.at[itr, 'time_linearohe'] = time_linearohe
                results_gV.at[itr, 'mse_lmmnn'] = mse_lmmnn
                results_gV.at[itr, 'time_lmmnn'] = time_lmmnn
                results_gV.at[itr, 'mse_merf'] = mse_merf
                results_gV.at[itr, 'time_merf'] = time_merf
                results_gV.at[itr, 'mse_armed'] = mse_armed
                results_gV.at[itr, 'time_armed'] = time_armed
                
                try:
                    mse_mixedlm, time_mixedlm, _, _ = MixedLM(df, to_drop='gE', mode=mode)
                    results_gV.at[itr, 'mse_mixedlm'] = mse_mixedlm
                    results_gV.at[itr, 'time_mixedlm'] = time_mixedlm
                except KeyError:
                    results_gV.at[itr, 'mse_mixedlm'] = None
                    results_gV.at[itr, 'time_mixedlm'] = None

                K.clear_session()
            
results_gV['Target_y'] = target_y
# Out:
#  0 intercept 3 10
# n_uniques:  [10]
# WARNING:tensorflow:From C:\Users\htals\AppData\Roaming\Python\Python311\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# WARNING  [module_wrapper.py:149] From C:\Users\htals\AppData\Roaming\Python\Python311\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# 11/11 [==============================] - 0s 1ms/step
#
#  1 intercept 3 30
# n_uniques:  [30]
# 11/11 [==============================] - 0s 1ms/step
#
#  2 intercept 3 50
# n_uniques:  [50]
# 11/11 [==============================] - 0s 1ms/step
#
#  3 intercept 3 70
# n_uniques:  [70]
# 11/11 [==============================] - 0s 2ms/step
#
#  4 intercept 3 90
# n_uniques:  [90]
# 11/11 [==============================] - 0s 1ms/step
#
#  5 intercept 3 110
# n_uniques:  [110]
# 11/11 [==============================] - 0s 1ms/step
#
#  6 intercept 3 130
# n_uniques:  [130]
# 11/11 [==============================] - 0s 1ms/step
#
#  7 intercept 3 150
# n_uniques:  [150]
# 11/11 [==============================] - 0s 1ms/step
#
#  8 intercept 3 170
# n_uniques:  [170]
# 11/11 [==============================] - 0s 1ms/step
#
#  9 intercept 3 190
# n_uniques:  [190]
# 11/11 [==============================] - 0s 1ms/step
#
#  10 intercept 3 210
# n_uniques:  [210]
# 11/11 [==============================] - 0s 1ms/step
#
#  11 intercept 3 230
# n_uniques:  [230]
# 11/11 [==============================] - 0s 1ms/step
#
#  12 intercept 3 250
# n_uniques:  [250]
# 11/11 [==============================] - 0s 1ms/step
#
#  13 intercept 4 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 1ms/step
#
#  14 intercept 4 30
# n_uniques:  [30]
# 11/11 [==============================] - 0s 1ms/step
#
#  15 intercept 4 50
# n_uniques:  [50]
# 11/11 [==============================] - 0s 1ms/step
#
#  16 intercept 4 70
# n_uniques:  [70]
# 11/11 [==============================] - 0s 1ms/step
#
#  17 intercept 4 90
# n_uniques:  [90]
# 11/11 [==============================] - 0s 1ms/step
#
#  18 intercept 4 110
# n_uniques:  [110]
# 11/11 [==============================] - 0s 1ms/step
#
#  19 intercept 4 130
# n_uniques:  [130]
# 11/11 [==============================] - 0s 1ms/step
#
#  20 intercept 4 150
# n_uniques:  [150]
# 11/11 [==============================] - 0s 1ms/step
#
#  21 intercept 4 170
# n_uniques:  [170]
# 11/11 [==============================] - 0s 1ms/step
#
#  22 intercept 4 190
# n_uniques:  [190]
# 11/11 [==============================] - 0s 1ms/step
#
#  23 intercept 4 210
# n_uniques:  [210]
# 11/11 [==============================] - 0s 991us/step
#
#  24 intercept 4 230
# n_uniques:  [230]
# 11/11 [==============================] - 0s 1ms/step
#
#  25 intercept 4 250
# n_uniques:  [250]
# 11/11 [==============================] - 0s 869us/step
#
#  26 intercept 5 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 1ms/step
#
#  27 intercept 5 30
# n_uniques:  [30]
# 11/11 [==============================] - 0s 1ms/step
#
#  28 intercept 5 50
# n_uniques:  [50]
# 11/11 [==============================] - 0s 928us/step
#
#  29 intercept 5 70
# n_uniques:  [70]
# 11/11 [==============================] - 0s 1ms/step
#
#  30 intercept 5 90
# n_uniques:  [90]
# 11/11 [==============================] - 0s 1ms/step
#
#  31 intercept 5 110
# n_uniques:  [110]
# 11/11 [==============================] - 0s 1ms/step
#
#  32 intercept 5 130
# n_uniques:  [130]
# 11/11 [==============================] - 0s 1ms/step
#
#  33 intercept 5 150
# n_uniques:  [150]
# 11/11 [==============================] - 0s 903us/step
#
#  34 intercept 5 170
# n_uniques:  [170]
# 11/11 [==============================] - 0s 964us/step
#
#  35 intercept 5 190
# n_uniques:  [190]
# 11/11 [==============================] - 0s 930us/step
#
#  36 intercept 5 210
# n_uniques:  [210]
# 11/11 [==============================] - 0s 1ms/step
#
#  37 intercept 5 230
# n_uniques:  [230]
# 11/11 [==============================] - 0s 1ms/step
#
#  38 intercept 5 250
# n_uniques:  [250]
# 11/11 [==============================] - 0s 1ms/step
#
#  39 intercept 6 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 1ms/step
#
#  40 intercept 6 30
# n_uniques:  [30]
# 11/11 [==============================] - 0s 1ms/step
#
#  41 intercept 6 50
# n_uniques:  [50]
# 11/11 [==============================] - 0s 940us/step
#
#  42 intercept 6 70
# n_uniques:  [70]
# 11/11 [==============================] - 0s 1ms/step
#
#  43 intercept 6 90
# n_uniques:  [90]
# 11/11 [==============================] - 0s 1ms/step
#
#  44 intercept 6 110
# n_uniques:  [110]
# 11/11 [==============================] - 0s 1ms/step
#
#  45 intercept 6 130
# n_uniques:  [130]
# 11/11 [==============================] - 0s 1ms/step
#
#  46 intercept 6 150
# n_uniques:  [150]
# 11/11 [==============================] - 0s 1ms/step
#
#  47 intercept 6 170
# n_uniques:  [170]
# 11/11 [==============================] - 0s 1ms/step
#
#  48 intercept 6 190
# n_uniques:  [190]
# 11/11 [==============================] - 0s 940us/step
#
#  49 intercept 6 210
# n_uniques:  [210]
# 11/11 [==============================] - 0s 1ms/step
#
#  50 intercept 6 230
# n_uniques:  [230]
# 11/11 [==============================] - 0s 1ms/step
#
#  51 intercept 6 250
# n_uniques:  [250]
# 11/11 [==============================] - 0s 1ms/step
#
#  52 intercept 7 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 1ms/step
#
#  53 intercept 7 30
# n_uniques:  [30]
# 11/11 [==============================] - 0s 944us/step
#
#  54 intercept 7 50
# n_uniques:  [50]
# 11/11 [==============================] - 0s 982us/step
#
#  55 intercept 7 70
# n_uniques:  [70]
# 11/11 [==============================] - 0s 1ms/step
#
#  56 intercept 7 90
# n_uniques:  [90]
# 11/11 [==============================] - 0s 1ms/step
#
#  57 intercept 7 110
# n_uniques:  [110]
# 11/11 [==============================] - 0s 5ms/step
#
#  58 intercept 7 130
# n_uniques:  [130]
# 11/11 [==============================] - 0s 1ms/step
#
#  59 intercept 7 150
# n_uniques:  [150]
# 11/11 [==============================] - 0s 1ms/step
#
#  60 intercept 7 170
# n_uniques:  [170]
# 11/11 [==============================] - 0s 1000us/step
#
#  61 intercept 7 190
# n_uniques:  [190]
# 11/11 [==============================] - 0s 1ms/step
#
#  62 intercept 7 210
# n_uniques:  [210]
# 11/11 [==============================] - 0s 1ms/step
#
#  63 intercept 7 230
# n_uniques:  [230]
# 11/11 [==============================] - 0s 992us/step
#
#  64 intercept 7 250
# n_uniques:  [250]
# 11/11 [==============================] - 0s 910us/step
#
#  65 intercept 8 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 4ms/step
#
#  66 intercept 8 30
# n_uniques:  [30]
# 11/11 [==============================] - 0s 1ms/step
#
#  67 intercept 8 50
# n_uniques:  [50]
# 11/11 [==============================] - 0s 1ms/step
#
#  68 intercept 8 70
# n_uniques:  [70]
# 11/11 [==============================] - 0s 1ms/step
#
#  69 intercept 8 90
# n_uniques:  [90]
# 11/11 [==============================] - 0s 1ms/step
#
#  70 intercept 8 110
# n_uniques:  [110]
# 11/11 [==============================] - 0s 950us/step
#
#  71 intercept 8 130
# n_uniques:  [130]
# 11/11 [==============================] - 0s 991us/step
#
#  72 intercept 8 150
# n_uniques:  [150]
# 11/11 [==============================] - 0s 1ms/step
#
#  73 intercept 8 170
# n_uniques:  [170]
# 11/11 [==============================] - 0s 1ms/step
#
#  74 intercept 8 190
# n_uniques:  [190]
# 11/11 [==============================] - 0s 1ms/step
#
#  75 intercept 8 210
# n_uniques:  [210]
# 11/11 [==============================] - 0s 1ms/step
#
#  76 intercept 8 230
# n_uniques:  [230]
# 11/11 [==============================] - 0s 1ms/step
#
#  77 intercept 8 250
# n_uniques:  [250]
# 11/11 [==============================] - 0s 1ms/step
#
#  78 slope 3 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 1ms/step
#
#  79 slope 3 30
# n_uniques:  [30]
# 11/11 [==============================] - 0s 1ms/step
#
#  80 slope 3 50
# n_uniques:  [50]
# 11/11 [==============================] - 0s 2ms/step
#
#  81 slope 3 70
# n_uniques:  [70]
# 11/11 [==============================] - 0s 1ms/step
#
#  82 slope 3 90
# n_uniques:  [90]
# 11/11 [==============================] - 0s 1ms/step
#
#  83 slope 3 110
# n_uniques:  [110]
# 11/11 [==============================] - 0s 1ms/step
#
#  84 slope 3 130
# n_uniques:  [130]
# 11/11 [==============================] - 0s 1ms/step
#
#  85 slope 3 150
# n_uniques:  [150]
# 11/11 [==============================] - 0s 982us/step
#
#  86 slope 3 170
# n_uniques:  [170]
# 11/11 [==============================] - 0s 1ms/step
#
#  87 slope 3 190
# n_uniques:  [190]
# 11/11 [==============================] - 0s 1ms/step
#
#  88 slope 3 210
# n_uniques:  [210]
# 11/11 [==============================] - 0s 1ms/step
#
#  89 slope 3 230
# n_uniques:  [230]
# 11/11 [==============================] - 0s 1ms/step
#
#  90 slope 3 250
# n_uniques:  [250]
# 11/11 [==============================] - 0s 1ms/step
#
#  91 slope 4 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 1ms/step
#
#  92 slope 4 30
# n_uniques:  [30]
# 11/11 [==============================] - 0s 1ms/step
#
#  93 slope 4 50
# n_uniques:  [50]
# 11/11 [==============================] - 0s 1ms/step
#
#  94 slope 4 70
# n_uniques:  [70]
# 11/11 [==============================] - 0s 1ms/step
#
#  95 slope 4 90
# n_uniques:  [90]
# 11/11 [==============================] - 0s 1ms/step
#
#  96 slope 4 110
# n_uniques:  [110]
# 11/11 [==============================] - 0s 1ms/step
#
#  97 slope 4 130
# n_uniques:  [130]
# 11/11 [==============================] - 0s 1ms/step
#
#  98 slope 4 150
# n_uniques:  [150]
# 11/11 [==============================] - 0s 1ms/step
#
#  99 slope 4 170
# n_uniques:  [170]
# 11/11 [==============================] - 0s 1ms/step
#
#  100 slope 4 190
# n_uniques:  [190]
# 11/11 [==============================] - 0s 1ms/step
#
#  101 slope 4 210
# n_uniques:  [210]
# 11/11 [==============================] - 0s 2ms/step
#
#  102 slope 4 230
# n_uniques:  [230]
# 11/11 [==============================] - 0s 2ms/step
#
#  103 slope 4 250
# n_uniques:  [250]
# 11/11 [==============================] - 0s 1ms/step
#
#  104 slope 5 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 2ms/step
#
#  105 slope 5 30
# n_uniques:  [30]
# 11/11 [==============================] - 0s 1ms/step
#
#  106 slope 5 50
# n_uniques:  [50]
# 11/11 [==============================] - 0s 1ms/step
#
#  107 slope 5 70
# n_uniques:  [70]
# 11/11 [==============================] - 0s 1ms/step
#
#  108 slope 5 90
# n_uniques:  [90]
# 11/11 [==============================] - 0s 1ms/step
#
#  109 slope 5 110
# n_uniques:  [110]
# 11/11 [==============================] - 0s 1ms/step
#
#  110 slope 5 130
# n_uniques:  [130]
# 11/11 [==============================] - 0s 1ms/step
#
#  111 slope 5 150
# n_uniques:  [150]
# 11/11 [==============================] - 0s 1ms/step
#
#  112 slope 5 170
# n_uniques:  [170]
# 11/11 [==============================] - 0s 1ms/step
#
#  113 slope 5 190
# n_uniques:  [190]
# 11/11 [==============================] - 0s 1ms/step
#
#  114 slope 5 210
# n_uniques:  [210]
# 11/11 [==============================] - 0s 4ms/step
#
#  115 slope 5 230
# n_uniques:  [230]
# 11/11 [==============================] - 0s 4ms/step
#
#  116 slope 5 250
# n_uniques:  [250]
# 11/11 [==============================] - 0s 1ms/step
#
#  117 slope 6 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 1ms/step
#
#  118 slope 6 30
# n_uniques:  [30]
# 11/11 [==============================] - 0s 1ms/step
#
#  119 slope 6 50
# n_uniques:  [50]
# 11/11 [==============================] - 0s 1ms/step
#
#  120 slope 6 70
# n_uniques:  [70]
# 11/11 [==============================] - 0s 1ms/step
#
#  121 slope 6 90
# n_uniques:  [90]
# 11/11 [==============================] - 0s 1ms/step
#
#  122 slope 6 110
# n_uniques:  [110]
# 11/11 [==============================] - 0s 2ms/step
#
#  123 slope 6 130
# n_uniques:  [130]
# 11/11 [==============================] - 0s 1ms/step
#
#  124 slope 6 150
# n_uniques:  [150]
# 11/11 [==============================] - 0s 1ms/step
#
#  125 slope 6 170
# n_uniques:  [170]
# 11/11 [==============================] - 0s 1ms/step
#
#  126 slope 6 190
# n_uniques:  [190]
# 11/11 [==============================] - 0s 1ms/step
#
#  127 slope 6 210
# n_uniques:  [210]
# 11/11 [==============================] - 0s 1ms/step
#
#  128 slope 6 230
# n_uniques:  [230]
# 11/11 [==============================] - 0s 2ms/step
#
#  129 slope 6 250
# n_uniques:  [250]
# 11/11 [==============================] - 0s 1ms/step
#
#  130 slope 7 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 1ms/step
#
#  131 slope 7 30
# n_uniques:  [30]
# 11/11 [==============================] - 0s 1ms/step
#
#  132 slope 7 50
# n_uniques:  [50]
# 11/11 [==============================] - 0s 1ms/step
#
#  133 slope 7 70
# n_uniques:  [70]
# 11/11 [==============================] - 0s 1ms/step
#
#  134 slope 7 90
# n_uniques:  [90]
# 11/11 [==============================] - 0s 1ms/step
#
#  135 slope 7 110
# n_uniques:  [110]
# 11/11 [==============================] - 0s 1ms/step
#
#  136 slope 7 130
# n_uniques:  [130]
# 11/11 [==============================] - 0s 1ms/step
#
#  137 slope 7 150
# n_uniques:  [150]
# 11/11 [==============================] - 0s 1ms/step
#
#  138 slope 7 170
# n_uniques:  [170]
# 11/11 [==============================] - 0s 1ms/step
#
#  139 slope 7 190
# n_uniques:  [190]
# 11/11 [==============================] - 0s 5ms/step
#
#  140 slope 7 210
# n_uniques:  [210]
# 11/11 [==============================] - 0s 4ms/step
#
#  141 slope 7 230
# n_uniques:  [230]
# 11/11 [==============================] - 0s 9ms/step
#
#  142 slope 7 250
# n_uniques:  [250]
# 11/11 [==============================] - 0s 33ms/step
#
#  143 slope 8 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 1ms/step
#
#  144 slope 8 30
# n_uniques:  [30]
# 11/11 [==============================] - 0s 2ms/step
#
#  145 slope 8 50
# n_uniques:  [50]
# 11/11 [==============================] - 0s 8ms/step
#
#  146 slope 8 70
# n_uniques:  [70]
# 11/11 [==============================] - 0s 5ms/step
#
#  147 slope 8 90
# n_uniques:  [90]
# 11/11 [==============================] - 0s 2ms/step
#
#  148 slope 8 110
# n_uniques:  [110]
# 11/11 [==============================] - 0s 8ms/step
#
#  149 slope 8 130
# n_uniques:  [130]
# 11/11 [==============================] - 0s 26ms/step
#
#  150 slope 8 150
# n_uniques:  [150]
# 11/11 [==============================] - 0s 13ms/step
#
#  151 slope 8 170
# n_uniques:  [170]
# 11/11 [==============================] - 0s 24ms/step
#
#  152 slope 8 190
# n_uniques:  [190]
# 11/11 [==============================] - 0s 10ms/step
#
#  153 slope 8 210
# n_uniques:  [210]
# 11/11 [==============================] - 0s 2ms/step
#
#  154 slope 8 230
# n_uniques:  [230]
# 11/11 [==============================] - 0s 2ms/step
#
#  155 slope 8 250
# n_uniques:  [250]
# 11/11 [==============================] - 0s 5ms/step
#
#  156 both 3 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 2ms/step
#
#  157 both 3 30
# n_uniques:  [30]
# 11/11 [==============================] - 0s 2ms/step
#
#  158 both 3 50
# n_uniques:  [50]
# 11/11 [==============================] - 0s 2ms/step
#
#  159 both 3 70
# n_uniques:  [70]
# 11/11 [==============================] - 0s 2ms/step
#
#  160 both 3 90
# n_uniques:  [90]
# 11/11 [==============================] - 0s 1ms/step
#
#  161 both 3 110
# n_uniques:  [110]
# 11/11 [==============================] - 0s 32ms/step
#
#  162 both 3 130
# n_uniques:  [130]
# 11/11 [==============================] - 0s 5ms/step
#
#  163 both 3 150
# n_uniques:  [150]
# 11/11 [==============================] - 0s 3ms/step
#
#  164 both 3 170
# n_uniques:  [170]
# 11/11 [==============================] - 0s 7ms/step
#
#  165 both 3 190
# n_uniques:  [190]
# 11/11 [==============================] - 0s 33ms/step
#
#  166 both 3 210
# n_uniques:  [210]
# 11/11 [==============================] - 0s 9ms/step
#
#  167 both 3 230
# n_uniques:  [230]
# 11/11 [==============================] - 0s 1ms/step
#
#  168 both 3 250
# n_uniques:  [250]
# 11/11 [==============================] - 0s 1ms/step
#
#  169 both 4 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 1ms/step
#
#  170 both 4 30
# n_uniques:  [30]
# 11/11 [==============================] - 0s 2ms/step
#
#  171 both 4 50
# n_uniques:  [50]
# 11/11 [==============================] - 0s 1ms/step
#
#  172 both 4 70
# n_uniques:  [70]
# 11/11 [==============================] - 0s 2ms/step
#
#  173 both 4 90
# n_uniques:  [90]
# 11/11 [==============================] - 0s 9ms/step
#
#  174 both 4 110
# n_uniques:  [110]
# 11/11 [==============================] - 0s 2ms/step
#
#  175 both 4 130
# n_uniques:  [130]
# 11/11 [==============================] - 0s 2ms/step
#
#  176 both 4 150
# n_uniques:  [150]
# 11/11 [==============================] - 0s 2ms/step
#
#  177 both 4 170
# n_uniques:  [170]
# 11/11 [==============================] - 0s 2ms/step
#
#  178 both 4 190
# n_uniques:  [190]
# 11/11 [==============================] - 0s 2ms/step
#
#  179 both 4 210
# n_uniques:  [210]
# 11/11 [==============================] - 0s 2ms/step
#
#  180 both 4 230
# n_uniques:  [230]
# 11/11 [==============================] - 0s 2ms/step
#
#  181 both 4 250
# n_uniques:  [250]
# 11/11 [==============================] - 0s 1ms/step
#
#  182 both 5 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 1ms/step
#
#  183 both 5 30
# n_uniques:  [30]
# 11/11 [==============================] - 0s 2ms/step
#
#  184 both 5 50
# n_uniques:  [50]
# 11/11 [==============================] - 0s 8ms/step
#
#  185 both 5 70
# n_uniques:  [70]
# 11/11 [==============================] - 0s 3ms/step
#
#  186 both 5 90
# n_uniques:  [90]
# 11/11 [==============================] - 0s 5ms/step
#
#  187 both 5 110
# n_uniques:  [110]
# 11/11 [==============================] - 0s 7ms/step
#
#  188 both 5 130
# n_uniques:  [130]
# 11/11 [==============================] - 0s 2ms/step
#
#  189 both 5 150
# n_uniques:  [150]
# 11/11 [==============================] - 0s 2ms/step
#
#  190 both 5 170
# n_uniques:  [170]
# 11/11 [==============================] - 0s 2ms/step
#
#  191 both 5 190
# n_uniques:  [190]
# 11/11 [==============================] - 0s 2ms/step
#
#  192 both 5 210
# n_uniques:  [210]
# 11/11 [==============================] - 0s 2ms/step
#
#  193 both 5 230
# n_uniques:  [230]
# 11/11 [==============================] - 1s 41ms/step
#
#  194 both 5 250
# n_uniques:  [250]
# 11/11 [==============================] - 0s 1ms/step
#
#  195 both 6 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 35ms/step
#
#  196 both 6 30
# n_uniques:  [30]
# 11/11 [==============================] - 0s 5ms/step
#
#  197 both 6 50
# n_uniques:  [50]
# 11/11 [==============================] - 0s 2ms/step
#
#  198 both 6 70
# n_uniques:  [70]
# 11/11 [==============================] - 0s 2ms/step
#
#  199 both 6 90
# n_uniques:  [90]
# 11/11 [==============================] - 0s 2ms/step
#
#  200 both 6 110
# n_uniques:  [110]
# 11/11 [==============================] - 0s 7ms/step
#
#  201 both 6 130
# n_uniques:  [130]
# 11/11 [==============================] - 1s 46ms/step
#
#  202 both 6 150
# n_uniques:  [150]
# 11/11 [==============================] - 0s 1ms/step
#
#  203 both 6 170
# n_uniques:  [170]
# 11/11 [==============================] - 0s 31ms/step
#
#  204 both 6 190
# n_uniques:  [190]
# 11/11 [==============================] - 0s 2ms/step
#
#  205 both 6 210
# n_uniques:  [210]
# 11/11 [==============================] - 0s 2ms/step
#
#  206 both 6 230
# n_uniques:  [230]
# 11/11 [==============================] - 0s 18ms/step
#
#  207 both 6 250
# n_uniques:  [250]
# 11/11 [==============================] - 0s 5ms/step
#
#  208 both 7 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 34ms/step
#
#  209 both 7 30
# n_uniques:  [30]
# 11/11 [==============================] - 0s 3ms/step
#
#  210 both 7 50
# n_uniques:  [50]
# 11/11 [==============================] - 0s 5ms/step
#
#  211 both 7 70
# n_uniques:  [70]
# 11/11 [==============================] - 0s 2ms/step
#
#  212 both 7 90
# n_uniques:  [90]
# 11/11 [==============================] - 0s 1ms/step
#
#  213 both 7 110
# n_uniques:  [110]
# 11/11 [==============================] - 0s 2ms/step
#
#  214 both 7 130
# n_uniques:  [130]
# 11/11 [==============================] - 0s 5ms/step
#
#  215 both 7 150
# n_uniques:  [150]
# 11/11 [==============================] - 0s 2ms/step
#
#  216 both 7 170
# n_uniques:  [170]
# 11/11 [==============================] - 0s 4ms/step
#
#  217 both 7 190
# n_uniques:  [190]
# 11/11 [==============================] - 0s 15ms/step
#
#  218 both 7 210
# n_uniques:  [210]
# 11/11 [==============================] - 0s 28ms/step
#
#  219 both 7 230
# n_uniques:  [230]
# 11/11 [==============================] - 0s 2ms/step
#
#  220 both 7 250
# n_uniques:  [250]
# 11/11 [==============================] - 0s 2ms/step
#
#  221 both 8 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 2ms/step
#
#  222 both 8 30
# n_uniques:  [30]
# 11/11 [==============================] - 1s 46ms/step
#
#  223 both 8 50
# n_uniques:  [50]
# 11/11 [==============================] - 0s 38ms/step
#
#  224 both 8 70
# n_uniques:  [70]
# 11/11 [==============================] - 0s 2ms/step
#
#  225 both 8 90
# n_uniques:  [90]
# 11/11 [==============================] - 0s 4ms/step
#
#  226 both 8 110
# n_uniques:  [110]
# 11/11 [==============================] - 0s 1ms/step
#
#  227 both 8 130
# n_uniques:  [130]
# 11/11 [==============================] - 0s 1ms/step
#
#  228 both 8 150
# n_uniques:  [150]
# 11/11 [==============================] - 0s 1ms/step
#
#  229 both 8 170
# n_uniques:  [170]
# 11/11 [==============================] - 0s 1ms/step
#
#  230 both 8 190
# n_uniques:  [190]
# 11/11 [==============================] - 0s 1ms/step
#
#  231 both 8 210
# n_uniques:  [210]
# 11/11 [==============================] - 0s 1ms/step
#
#  232 both 8 230
# n_uniques:  [230]
# 11/11 [==============================] - 0s 2ms/step
#
#  233 both 8 250
# n_uniques:  [250]
# 11/11 [==============================] - 0s 31ms/step

# %%
results_gV.head()
# Out:
#         mode   seed   gE    gV  mse_Linear_Exclude_Group  \
# 0  intercept  100.0  3.0  10.0                 94.931903
# 1  intercept  100.0  3.0  30.0                 94.931903
# 2  intercept  100.0  3.0  50.0                 94.931903
# 3  intercept  100.0  3.0  70.0                 94.931903
# 4  intercept  100.0  3.0  90.0                 94.931903
#
#    time_Linear_Exclude_Group  mse_Linear_Include_Group  \
# 0                   0.039198                 19.841003
# 1                   0.003843                 20.906742
# 2                   0.002581                 20.518089
# 3                   0.004000                 20.942659
# 4                   0.004004                 20.872792
#
#    time_Linear_Include_Group  mse_linearohe  time_linearohe  mse_lmmnn  \
# 0                   0.007006      11.393541        0.004674  11.330379
# 1                   0.004031      11.695126        0.007340  11.706294
# 2                   0.002999      16.550525        0.005973  11.933528
# 3                   0.003999      12.310774        0.005997  12.721486
# 4                   0.003994      13.152714        0.009660  13.711466
#
#    time_lmmnn   mse_merf  time_merf  mse_armed  time_armed  mse_mixedlm  \
# 0   18.965990  14.688880   1.053128  22.434624   31.582309    10.935210
# 1   18.011672  14.466502   1.424131  25.756082   32.861017    11.533671
# 2   18.155776  13.796640   1.265707  32.863062   32.674869    11.922151
# 3   18.344752  13.826264   1.387881  38.022721   36.072366    11.507119
# 4   18.730732  14.134351   1.547196  42.521903   33.206537    11.674394
#
#    time_mixedlm                                           Target_y
# 0      0.040318  [-17.32423698649145, -9.767000606453818, -8.83...
# 1      0.065628  [-17.32423698649145, -9.767000606453818, -8.83...
# 2      0.100233  [-17.32423698649145, -9.767000606453818, -8.83...
# 3      0.138972  [-17.32423698649145, -9.767000606453818, -8.83...
# 4      0.140212  [-17.32423698649145, -9.767000606453818, -8.83...

# %%
results_gV.to_csv(r"D:\Notes\Sem - 6\Thesis\Mixed Effect Model\Lit\Notebooks\Thesis_final\Results\r6_single.csv", index=False)

# %%
res = pd.read_csv(r"D:\Notes\Sem - 6\Thesis\Mixed Effect Model\Lit\Notebooks\Thesis_Experiments\Experiment_3_multiple_features.csv", index_col = False)
res
# Out:
#           mode   seed   gE     gV  mse_Linear_Exclude_Group  \
# 0    intercept  100.0  3.0   10.0                 62.932739
# 1    intercept  100.0  3.0   30.0                 59.953587
# 2    intercept  100.0  3.0   50.0                 53.125932
# 3    intercept  100.0  3.0   70.0                 54.782235
# 4    intercept  100.0  3.0   90.0                 61.799338
# ..         ...    ...  ...    ...                       ...
# 229       both  100.0  8.0  170.0                 97.127035
# 230       both  100.0  8.0  190.0                 97.243850
# 231       both  100.0  8.0  210.0                108.240863
# 232       both  100.0  8.0  230.0                111.739119
# 233       both  100.0  8.0  250.0                106.443157
#
#      time_Linear_Exclude_Group  mse_Linear_Include_Group  \
# 0                     0.004973                 46.830245
# 1                     0.000000                 50.633843
# 2                     0.000000                 53.051195
# 3                     0.016877                 54.625546
# 4                     0.000000                 61.738107
# ..                         ...                       ...
# 229                   0.015677                 97.542689
# 230                   0.000000                 96.159347
# 231                   0.016695                107.931581
# 232                   0.000000                112.034853
# 233                   0.000000                106.749175
#
#      time_Linear_Include_Group  mse_linearohe  time_linearohe  mse_lmmnn  \
# 0                     0.003601   1.174462e+01        0.010418  11.620501
# 1                     0.000000   1.227331e+01        0.001020  12.190366
# 2                     0.016661   1.229426e+01        0.000000  12.360249
# 3                     0.000000   1.280597e+01        0.015635  12.840295
# 4                     0.016727   1.367928e+01        0.000000  13.598160
# ..                         ...            ...             ...        ...
# 229                   0.000000   8.822612e+01        0.133209  77.089952
# 230                   0.083264   9.738019e+01        0.072102  82.817802
# 231                   0.000000   1.958113e+23        0.016497  80.521319
# 232                   0.000000   5.346069e+23        0.016829  89.277500
# 233                   0.000000   3.891755e+28        0.049969  96.830407
#
#      time_lmmnn   mse_merf  time_merf   mse_armed  time_armed  mse_mixedlm  \
# 0     18.314671  14.282424   1.450588   16.445197   33.978938    11.257955
# 1     18.630861  17.377580   1.566107   20.129311   33.961105    11.775194
# 2     18.447531  17.525701   1.817029   23.452656   33.492830    12.283605
# 3     18.247669  21.970372   2.082715   29.739456   48.827548    11.790988
# 4     18.914160  24.199315   1.982780   32.768645   45.527563    12.198191
# ..          ...        ...        ...         ...         ...          ...
# 229   30.629533  81.035910   2.733636   77.366070   51.462017    18.822022
# 230   25.350312  85.823642   2.615967   87.856319   48.213266    20.087284
# 231   23.780323  91.187697   2.716972   92.059910   48.613112    19.626007
# 232   24.180134  96.559668   2.882629  101.131835   49.789888    20.922500
# 233   23.897908  96.913913   4.249073  104.425319   50.169633    28.008263
#
#      time_mixedlm                                           Target_y
# 0        0.066625  [-11.71877472679137, -7.557713673917831, -1.00...
# 1        0.108311  [-11.71877472679137, -7.557713673917831, -1.00...
# 2        0.138708  [-11.71877472679137, -7.557713673917831, -1.00...
# 3        0.322070  [-11.71877472679137, -7.557713673917831, -1.00...
# 4        0.388452  [-11.71877472679137, -7.557713673917831, -1.00...
# ..            ...                                                ...
# 229     10.383256  [-6.039071242283073, -3.162102979153872, 11.00...
# 230     11.173110  [-8.192536661546917, -2.9118257246764716, 11.6...
# 231     15.817049  [-5.747770947676486, -3.9236095329053033, 14.4...
# 232     16.086584  [-4.820039070088485, -2.803497622019455, 11.26...
# 233     17.940537  [-4.747653825414979, -3.3361340782934774, 13.2...
#
# [234 rows x 19 columns]

# %%
viz.plot_ALL_model_comparision_range_individual_effective_group(res[res['mode'] == 'both'], use_rmse=False)
plt.savefig(r"D:\Notes\Sem - 6\Thesis\Mixed Effect Model\Lit\Notebooks\Report\Experiments\Multiple_ALL_both.pdf", format = 'pdf',bbox_inches='tight')

# %%
viz.plot_combined_model_comparision_mean_performance_individual_effective_group(res[res['mode'] == 'both'], 5, use_rmse=True)
plt.savefig(r"D:\Notes\Sem - 6\Thesis\Mixed Effect Model\Lit\Notebooks\Report\Experiments\Multiple_ALL_both_5.pdf", format = 'pdf',bbox_inches='tight')

# %% [markdown]
# # Effective Group Performance

# %%
results_gE = pd.DataFrame([])

effectives = list(range(3,9))
groups = [10]
itr = -1
target_y = []
modes = ['intercept', 'slope', 'both']

for mode in modes:
    
    for e in effectives:

        for v in groups:

            seeds = [100]

            for s in seeds:

                itr = itr + 1
                print("\n",itr,mode,e,v)

                df,_ = sd.create_data_linspace(1000, e, v, 5, mode=mode, random_seed = s,\
                                               shuffle_groups=True ,re_error=(0, 0))
                np.random.seed(s)
                df['y'] = df.y + np.random.normal(0,3, size = len(df))
                target_y.append(list(df.y))

                mse_Linear_Exclude_Group, time_Linear_Exclude_Group,_,_ = Linear_Exclude_Group(df)
                mse_Linear_Include_Group, time_Linear_Include_Group,_,_ = Linear_Include_Group(df, to_drop='gE')
                mse_linearohe, time_linearohe,_,_ = LinearOHE(df, to_drop='gE')
                mse_lmmnn, time_lmmnn,_,_ = LMMNN(df, to_drop='gE')
                mse_merf, time_merf,_,_ = MERForest(df, to_drop='gE', threshold=0.1)
                mse_armed, time_armed,_,_ = ARMED(df, to_drop='gE')

                results_gE.at[itr, 'mode'] = mode
                results_gE.at[itr, 'seed'] = s
                results_gE.at[itr, 'gE'] = e
                results_gE.at[itr, 'gV'] = v

                results_gE.at[itr, 'mse_Linear_Exclude_Group'] = mse_Linear_Exclude_Group
                results_gE.at[itr, 'time_Linear_Exclude_Group'] = time_Linear_Exclude_Group
                results_gE.at[itr, 'mse_Linear_Include_Group'] = mse_Linear_Include_Group
                results_gE.at[itr, 'time_Linear_Include_Group'] = time_Linear_Include_Group
                results_gE.at[itr, 'mse_linearohe'] = mse_linearohe
                results_gE.at[itr, 'time_linearohe'] = time_linearohe
                results_gE.at[itr, 'mse_lmmnn'] = mse_lmmnn
                results_gE.at[itr, 'time_lmmnn'] = time_lmmnn
                results_gE.at[itr, 'mse_merf'] = mse_merf
                results_gE.at[itr, 'time_merf'] = time_merf
                results_gE.at[itr, 'mse_armed'] = mse_armed
                results_gE.at[itr, 'time_armed'] = time_armed
                
                try:
                    mse_mixedlm, time_mixedlm, _, _ = MixedLM(df, to_drop='gE', mode=mode)
                    results_gE.at[itr, 'mse_mixedlm'] = mse_mixedlm
                    results_gE.at[itr, 'time_mixedlm'] = time_mixedlm
                except KeyError:
                    results_gE.at[itr, 'mse_mixedlm'] = None
                    results_gE.at[itr, 'time_mixedlm'] = None

                K.clear_session()
            
results_gE['Target_y'] = target_y
# Out:
#  0 intercept 3 10
# n_uniques:  [10]
# WARNING:tensorflow:From C:\Users\htals\AppData\Roaming\Python\Python311\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# WARNING  [module_wrapper.py:149] From C:\Users\htals\AppData\Roaming\Python\Python311\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# 11/11 [==============================] - 0s 1ms/step
#
#  1 intercept 4 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 1ms/step
#
#  2 intercept 5 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 11ms/step
#
#  3 intercept 6 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 952us/step
#
#  4 intercept 7 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 1ms/step
#
#  5 intercept 8 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 1ms/step
#
#  6 slope 3 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 1ms/step
#
#  7 slope 4 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 1ms/step
#
#  8 slope 5 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 1ms/step
#
#  9 slope 6 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 14ms/step
#
#  10 slope 7 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 1ms/step
#
#  11 slope 8 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 2ms/step
#
#  12 both 3 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 886us/step
#
#  13 both 4 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 2ms/step
#
#  14 both 5 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 1ms/step
#
#  15 both 6 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 840us/step
#
#  16 both 7 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 1ms/step
#
#  17 both 8 10
# n_uniques:  [10]
# 11/11 [==============================] - 0s 901us/step

# %%
results_gE.to_csv(r"D:\Notes\Sem - 6\Thesis\Mixed Effect Model\Lit\Notebooks\Thesis_Experiments\Experiment_3_multiple_features_effective_performance.csv", index=False)
